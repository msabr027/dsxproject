// %% [markdown]
// # Product revenue prediction with the SPSS Machine Learning API
//
// This Scala 2.10 notebook shows you how to create a predictive model by using IBM SPSS Algorithm on Apache Spark v1.6. You'll learn how to create an SPSS random tree model by using the IBM SPSS Machine Learning API, and how to view the model with IBM SPSS Model Viewer.
//
// In this notebook, you'll create a model with telecommunications data to predict when its customers will leave for a competitor, so that you can take some action to retain the customer. We developped prediction model on Google Analytics dataset whit the summary statistics of the model. The dataset is about transactional from source (Google Analytics)of e-commerce site that we will use to build a predictive analysis of product revenue.
//
// To get the most out of this notebook, you should have some familiarity with the Scala programming language.
//
// ## Contents
// This notebook contains the following main sections:
//
// 1. [Load the Web analytics Data with DSX  "Find and add Data" tab.](#overview)
// 1. [Build your model.](#prepare)
// 1. [Export the XML files (PMML, StatXML) for other detail statistics.](#analyze)
// 1. [Visualization tool for Model visualizations.](#view)

// %% [markdown]
// <a id="overview"></a>
// ## 1. Load the Web analytics Data with DSX  "Find and add Data" tab.
//
// We have collected list of necessary variables from available Google analytics dataset for predictive model development, which are
//
//     yitemrevenue – Item Revenue at Rs
//     xcartadd – Numbers of instance added to cart
//     xcartuniqadd – Numbers of unique instance added to cart
//     xcartaddtotalrs –Total Rs value of products after they are added to cart
//     xcartremove- Numbers of instances removed from cart
//     xcardtremovetotal – Total numbers of instances removed from cart
//     xcardtremovetotalrs – Total  Rs after numbers of instances removed from cart
//     xproductviews – Numbers of page views
//     xuniqprodview – Numbers of uniqe product views
//     xprodviewinrs – Rs at total numbers of page views

// %%
// The code was removed by DSX for sharing.
// Out:
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+
// |yitemrevenue|xcartadd|xcartuniqadd|xcartaddtotalrs|xcartremove|xcardtremovetotal|xcardtremovetotalrs|xproductviews|xuniqprodview|xprodviewinrs|
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+
// |    39215.93|     614|         503|         752186|         10|               10|              11990|        24306|        20498|          299|
// |    23819.47|     833|         622|         425667|          8|                5|               3992|        11171|         8718|          571|
// |     4415.45|     122|         101|         121878|          2|                2|               1998|         6926|         6017|      6919074|
// |    57435.56|     239|         196|         609761|          2|                2|               4998|        11250|         9733|         2834|
// |         0.0|      32|          22|          58488|          0|                0|                  0|          872|          764|      1745628|
// |      9181.9|      79|          56|          63121|          2|                1|               1598|         1587|         1232|      1281213|
// |     4135.44|      23|          22|          35857|          0|                0|                  0|         1075|          842|      1685285|
// |     8906.24|      82|          54|         104078|          4|                3|               5036|         1214|          848|      1554466|
// |    12722.89|      79|          68|          95521|          0|                0|                  0|         1214|          904|      1474786|
// |         0.0|       6|           6|          19770|          0|                0|                  0|          636|          514|      2081844|
// |     9545.37|      16|          13|          64784|          0|                0|                  0|          951|          741|      3470649|
// |     1166.32|      12|          10|          16708|          0|                0|                  0|          731|          581|       990589|
// |     3153.93|      21|          16|          24969|          5|                1|               5945|          964|          795|      1149396|
// |     2907.67|      13|          13|          19447|          0|                0|                  0|          747|          625|      2362203|
// |         0.0|       3|           2|           4497|          0|                0|                  0|          334|          241|       505166|
// |     2756.96|      19|          13|          30661|          6|                3|               9354|         1115|          875|      1759085|
// |     1378.48|      44|          30|          70676|          1|                1|               1559|          900|          697|      1414540|
// |         0.0|      23|          17|          46377|          0|                0|                  0|          868|          729|      1965632|
// |      463.47|      15|          13|           8085|          0|                0|                  0|         1478|         1331|       776497|
// |         0.0|      17|          14|          49215|          0|                0|                  0|          543|          437|      1553025|
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+
// only showing top 20 rows

// %% [markdown]
// <a id="prepare"></a>
// ## 2. Build your model.
//
// After collecting the necessary data, we are ready to develop predictive model. Here, we require a response variable and explanatory variables for regression modeling. The element which is predicted is called the response variable. The variables by which we are going to predict the response variable are called the explanatory variables. In the next part, we will develop model with regression tool.

// %%
import com.ibm.spss.ml.classificationandregression.GeneralizedLinear
import com.ibm.spss.ml.classificationandregression.params.Effect

val linearRegression = GeneralizedLinear().
setInputFieldList(Array("xcartadd", "xcartuniqadd", "xcartaddtotalrs","xcartremove", "xcardtremovetotal","xcardtremovetotalrs", "xproductviews","xuniqprodview", "xprodviewinrs")).
setTargetField("yitemrevenue").
setDistribution("NORMAL").
setLinkFunction("IDENTITY").
setEffects(List(
  Effect(List("xcartadd"), List(0)),
  Effect(List("xcartuniqadd"), List(0)),
  Effect(List("xcartaddtotalrs"), List(0)),
  Effect(List("xcartremove"), List(0)),
  Effect(List("xcardtremovetotal"), List(0)),
  Effect(List("xcardtremovetotalrs"), List(0)),
  Effect(List("xproductviews"), List(0)),
  Effect(List("xuniqprodview"), List(0)),
  Effect(List("xprodviewinrs"), List(0))
  ))

val linearRegressionModel = linearRegression.fit(dfData1) 


val predictions1 = linearRegressionModel.transform(dfData1)

val predResultNew = predictions1.withColumn("prediction", predictions1("prediction").cast("double"))
predResultNew.show()
// Out:
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+------------------+
// |yitemrevenue|xcartadd|xcartuniqadd|xcartaddtotalrs|xcartremove|xcardtremovetotal|xcardtremovetotalrs|xproductviews|xuniqprodview|xprodviewinrs|        prediction|
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+------------------+
// |    39215.93|     614|         503|         752186|         10|               10|              11990|        24306|        20498|          299|43788.412597407325|
// |    23819.47|     833|         622|         425667|          8|                5|               3992|        11171|         8718|          571|22004.207857393754|
// |     4415.45|     122|         101|         121878|          2|                2|               1998|         6926|         6017|      6919074| 8171.245497375272|
// |    57435.56|     239|         196|         609761|          2|                2|               4998|        11250|         9733|         2834|  47996.4434793601|
// |         0.0|      32|          22|          58488|          0|                0|                  0|          872|          764|      1745628| 5712.486207388134|
// |      9181.9|      79|          56|          63121|          2|                1|               1598|         1587|         1232|      1281213| 5435.109287336933|
// |     4135.44|      23|          22|          35857|          0|                0|                  0|         1075|          842|      1685285|3340.3504940315847|
// |     8906.24|      82|          54|         104078|          4|                3|               5036|         1214|          848|      1554466| 8841.984165026104|
// |    12722.89|      79|          68|          95521|          0|                0|                  0|         1214|          904|      1474786| 7326.627534990236|
// |         0.0|       6|           6|          19770|          0|                0|                  0|          636|          514|      2081844| 2604.028222160514|
// |     9545.37|      16|          13|          64784|          0|                0|                  0|          951|          741|      3470649| 8035.162511911736|
// |     1166.32|      12|          10|          16708|          0|                0|                  0|          731|          581|       990589|1700.7132982602138|
// |     3153.93|      21|          16|          24969|          5|                1|               5945|          964|          795|      1149396| 2509.305166742186|
// |     2907.67|      13|          13|          19447|          0|                0|                  0|          747|          625|      2362203|2097.4227138553265|
// |         0.0|       3|           2|           4497|          0|                0|                  0|          334|          241|       505166| 680.7541150300865|
// |     2756.96|      19|          13|          30661|          6|                3|               9354|         1115|          875|      1759085|1528.7561871092291|
// |     1378.48|      44|          30|          70676|          1|                1|               1559|          900|          697|      1414540| 6320.985135884398|
// |         0.0|      23|          17|          46377|          0|                0|                  0|          868|          729|      1965632| 4856.382588395406|
// |      463.47|      15|          13|           8085|          0|                0|                  0|         1478|         1331|       776497|-383.0450589108769|
// |         0.0|      17|          14|          49215|          0|                0|                  0|          543|          437|      1553025| 4972.808911772145|
// +------------+--------+------------+---------------+-----------+-----------------+-------------------+-------------+-------------+-------------+------------------+
// only showing top 20 rows

// %% [markdown]
// <a id="analyze"></a>
// ### 3. Export the XML files (PMML, StatXML) for other detail statistics.
// By exporting your results to different formats, such as Predictive Model Markup Language (PMML) or statXML format you can share your statistical analyses outside of IBM Data Science Experience.

// %%
import java.io.{File, PrintWriter}

linearRegressionModel.toPMML("lRM_pmml.xml")
val statXML = linearRegressionModel.statXML()
new PrintWriter("StatXML.xml") {
      write(statXML)
      close
}
// Out:
// $iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$iwC$$anon$1@e79a25e7

// %% [markdown]
// <a id="view"></a>
// ### 4. Visualization tool for Model visualizations.
//
// SPSS visualizations offer interactive tables and charts to help you evaluate and improve a predictive analytics model.
//
// These SPSS visualizations provide one comprehensive set of output so that you don't need to create multiple charts and tables to determine model performance.

// %%
import com.ibm.spss.scala.ModelViewer

val html = ModelViewer.toHTML(linearRegressionModel)
kernel.magics.html(html)
// Out:
// <div style="height: 700px;">
// <!DOCTYPE HTML>
// <html lang="en">
//   <head>
// <meta charset="UTF-8">
//     <title data-mdlvr-modelType="spss.generalizedLinearEngine" data-mdlvr-itemNames="table.ModelInformations;table.RecordsSummary;table.TestsofModelEffectsTable;table.ParameterEstimates;chart.ResidualsByPredictedJS;chart.ResidualHistogramJS;">Model Visualization</title>
//     <script>
//        var CONST_DICTIONARY = {
//          baseURI: 'https://model-viewer.mybluemix.net',
//          Copied: 'Copied!',
//          style: 'dark',
//        };
//     </script>
//
//     <!-- Global Model Visualization includes -->
//     <link rel="stylesheet" type="text/css" href="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/stylesheets/modelViewer.css">
//     <link rel="stylesheet" type="text/css" href="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/stylesheets/modelViewerChart.css">
//     <link rel="stylesheet" type="text/css" href="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/stylesheets/modelViewerTable.css">
//     <link rel="stylesheet" type="text/css" href="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/stylesheets/dark/looks.css">
//     <script src="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/javascripts/modelViewerChart.js"></script>
//     <script src="https://model-viewer.mybluemix.net/mdlvr/assets/1.0.0/javascripts/modelViewerTable.js"></script>
//     <script type="text/javascript">
//        $(function() {
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1');
//           $(this).addClass('active');
//         });
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_2').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_2');
//           $(this).addClass('active');
//         });
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_3').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_3');
//           $(this).addClass('active');
//         });
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_4').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_4');
//           $(this).addClass('active');
//         });
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_5').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_5');
//           $(this).addClass('active');
//         });
//
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_6').click(function() {
//           divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_6');
//           $(this).addClass('active');
//         });
//
//         divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb('modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1');
//         $('#showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1').addClass('active');
//
//        });
//
//     	function divSwitcher_3b054e99_1d45_444f_a053_5e4c6ec895eb(divToShow) {
//     	  $('.modelVisualizationDiv_3b054e99_1d45_444f_a053_5e4c6ec895eb').each(function(index) {
//          if ($(this).attr("id") == divToShow) {
//             var elementDiv = $('.vDiv', $( this ));
//            $('#vTitle1_3b054e99_1d45_444f_a053_5e4c6ec895eb').html(elementDiv.attr("data-t1"));
//            var fIdx = 1;
//            var footAttr = "data-foot" + fIdx;
//            var titleTooltip = "";
//            if ( null != elementDiv.attr(footAttr)  )
//            {
//              // footnotes present
//              var footNums = "";
//              while ( null != elementDiv.attr(footAttr) )
//              {
//                footNums += "<div class='table_tooltip_right'><span class='table_footnote_title1_superscript'>[" + fIdx + "]</span><span class='table_tooltip_title1_text'>" + elementDiv.attr(footAttr)+"</span></div>";
//                fIdx += 1;
//                footAttr = "data-foot" + fIdx;
//              }
//              $('#vTitle1_3b054e99_1d45_444f_a053_5e4c6ec895eb').append(footNums);
//            }
//            if ( $('.vDiv', $(this)).attr("data-t3") != null) {
//              $('#vTitle1_3b054e99_1d45_444f_a053_5e4c6ec895eb').append($('.vDiv', $( this )).attr("data-t3"));
//            }
//            $('#vTitle2_3b054e99_1d45_444f_a053_5e4c6ec895eb').html($('.vDiv', $( this )).attr("data-t2"));
//            if($(this).is(":visible") == false) {
//              if ($(this).parents('.output_subarea').length > 0) {
//                $('.mv-table-spacer').css('height', 'calc(100% - 40px)');
//                console.log('Model Viewer : Detected DSX/Notebook.');
//              }
//              if (typeof d3 != 'undefined')
//                d3.select(this).selectAll("svg > *").remove();
//              $(this).show();
//              var htmlString = $(this).html();
//              $(this).html(htmlString);
//              MdlVizCollapsibleLists.apply();
//              $(this).scrollTop( 0 );
//              MdlVizTable.addTableCellHandlers(this);
//            }
//            if(typeof sizeOutputItem != 'undefined') {
//            }
//          } else {
//            $(this).hide();
//          }
//        });
//        $('.showModelVisualizationMenuItem_3b054e99_1d45_444f_a053_5e4c6ec895eb').each(function(index) {
//          $(this).removeClass("active");
//        });
//      }
//
//      function initDataTablesTable(item, initSettings) {
//      }
//
//     </script>
//     <script>
//       $(window).load(function() {
//         var vl = document.getElementsByClassName('loading');
//         for(var i = 0; i < vl.length; i++) {
//           vl[i].style.display = 'none';
//         }
//
//         $('#modelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1').fadeIn('slow');
//
//       });
//     </script>
//   </head>
//   <body style="overflow: hidden;" data-model-viewer-uuid="_3b054e99_1d45_444f_a053_5e4c6ec895eb">
//
//
//     <div id="left_pane_div_3b054e99_1d45_444f_a053_5e4c6ec895eb" class="mdlvr left_pane_div">
//       <div class="leftTitle">Generalized Linear Model
// 		<div class='MVInfotooltip'>
// 			<a class='infodot' style='background-image: url(https://model-viewer.mybluemix.net/mdlvr/assets/images/dark/info_small_18.svg);'></a>
// 				<span class='MVInfotooltiptext'>Logistic regression is among the most popular models for predicting binary targets. It yields a linear prediction function that is transformed to produce predicted probabilities of response for scoring observations and coefficients that are easily transformed into odds ratios, which are useful measures of predictor effects on response probabilities. The Data Science Experience implementation includes options for predictor or feature selection and a measure of relative predictor importance.<br />For more information, visit the <a href="http://datascience.ibm.com/docs/content/analyze-data/spss-visualization.html">Model visualizations page</a> in the Data Science Experience web site.</span>
// 		</div>
//       </div>
//       <hr class="leftSectionSplitter">
//       <ul class="menuList">
//       <li class="menuList"><a class="showModelVisualizationMenuItem_3b054e99_1d45_444f_a053_5e4c6ec895eb active" id="showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_1" data-mv-type="table">Model Information</a></li>
//       <li class="menuList"><a class="showModelVisualizationMenuItem_3b054e99_1d45_444f_a053_5e4c6ec895eb" id="showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_2" data-mv-type="table">Records Summary</a></li>
//       <li class="menuList"><a class="showModelVisualizationMenuItem_3b054e99_1d45_444f_a053_5e4c6ec895eb" id="showModelVisualization_3b054e99_1d45_444f_a053_5e4c6ec895eb_3" data-mv-type="table">Tests of Model Effects</a></li>
//       <li class="menuList"><a class="showModelVisualizationMenuItem_3b054e99_1d45_444f_a053_5e4c6ec895eb" id="showModelVi
